# %%
#string concatenation
string1 = "Hello "
name = input("Enter your Name: ")

string2 = string1 + name

print(string2)
# Out:
# Enter your Name:  Karthika
# Hello Karthika

# %%
string3=", welcome to Python programming"

string_output = string2+string3

print(string_output)
# Out:
# Hello Karthika, welcome to Python programming

# %%
#string slicing and Indexing
string = string_output
string='Hello Karthika, welcome to Python programming'
print(string[0])
# Out:
# H

# %%
print(string[-1])
# Out:
# g

# %%
print(string[:5])
# Out:
# Hello

# %%
print(string[-11:])
# Out:
# programming

# %%
print(string[::-1])
# Out:
# gnimmargorp nohtyP ot emoclew ,akihtraK olleH

# %%
string='Hello Karthika, welcome to Python programming'
print(string[27:33])
# Out:
# Python

# %%
#String Methods
strM = "Python beginner tutorial"

# %%
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print(strM.count('t'))
# Out:
# 3

# %%
print(strM.replace('Python','Machine Learning'))
# Out:
# Machine Learning beginner tutorial

# %%
#Tuples
t1=(10,20,30)
t2=(40,50,60)
t_combine=tuple(t1+t2)
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
